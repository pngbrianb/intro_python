# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Measuring the Effectiveness of a Warning Sign Placement
#
# In this problem we'll be looking at the amis data set from [this](https://vincentarelbundock.github.io/Rdatasets/datasets.html) collection. The data represents measured speeds of cars along roads that have warning sides compared to similar roads without such signs.
#
# The following is the **data dictionary** for this data set. In data science, data dictionaries play a key role in describing the meaning of data. They give the names, data types and meaning of each column.
#
# | Column  | Data Type | Description                                                                                                                                                                                                                                                                             |
# |---------|-----------|-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | speed   | int       | Speeds of cars (in miles per hour)                                                                                                                                                                                                                                                      |
# | period  | int       | A numeric column indicating the time that the reading was taken. A value of 1 indicates a reading taken before the sign was erected, a 2 indicates a reading taken shortly after erection of the sign and a 3 indicates a reading taken after the sign had been in place for some time. |
# | warning | int       | A numeric column indicating whether the location of the reading was chosen to have a warning sign erected. A value of 1 indicates presence of a sign and a value of 2 indicates that no sign was erected.                                                                               |
# | pair    | int       | A numeric column giving the pair number at which the reading was taken. Pairs were numbered from 1 to 14.                                                                                                                                                                               |
#
# ## Question: What was the long-term effect on average cars' speeds of placing the sign in Pair 7?

# %% [markdown]
# Before we can do anything with our data, we'll need to import pandas.
#
# Write your import below:

# %%
# import pandas:

# %% [markdown]
# Now we read the data from its web address, assigning it to our new dataframe, `df`:

# %%
df = pd.read_csv(
    "https://vincentarelbundock.github.io/Rdatasets/csv/boot/amis.csv",
    usecols=range(1,5)
)

# %% [markdown]
# Just to get a look at our dataframe, let's display our first five rows:

# %% [markdown]
# ... and, let's see some other useful information

# %%
df.info()

# %% [markdown]
# In solving any coding problem, it's usually a good idea to start by considering the output of our program. What should the end result look like?
#
# Let's say our output should print:
# ```
# average speed before sign: <the average speed at period 1>
# average speed after sign: <the average speed at period 1>
# ```
#
# Each row in `df` is a single car's speed. So, we'll have to write a function to find the average of the speeds before and after the sign is placed. Define a function called `avg_speed` below that takes a list of speeds and calulates the average.
#
# **Hint:** some built-in functions that work with lists include `len()`, which gives the number of items in a list, and `sum()` which tells you the sum of a collection of numbers

# %%
# Write your avg_speed function:

# %% [markdown]
# Now, since we know what our output will look like, we can define our target variables and write our print statement!

# %%
# define some (empty) lists


# and go ahead and write your print statements:

# %% [markdown]
# Did you run the cell and get a divide by zero error? That's okay! The tricky part now is to fill in the middle of our program.
#
# The `.values` attribute of a data frame will give us all of our rows. Here, this helps us because we can **iterate over each row**!
#
# Try slicing to examine the first row of `df` using this method.
# **Hint:** indices in Python start at 0

# %%
# display the first row of df:

# %% [markdown]
# Those numbers may not look like an answer to our question, but we can slice each *value* out of this single row again. Try just getting the first number, the `'speed'` of this car.

# %%
# get the first row's speed below:

# %% [markdown]
# Now let's just refresh our memories of which column is which:
#
# **Hint:** use the `columns()` function

# %%
# Display the column names:

# %% [markdown]
# And if we remember our `if/else` logic we can use all this information to answer our question! Remember, we are looking for:
#
# - The location `'pair'` of `7`
# - Where there WAS a sign (`'warning` value of `1`)
# - Speeds before there was a sign (`'period'` of `1`)
# - Speeds after there was a sign (`'period'` of `3`)
#
# Write your control flows below (do you remember how to add values to a list?):

# %%
# loop through each row and select out the relevant columns:

# %% [markdown]
# ### Now combine all the code into one cell!

# %%
# define your variables, run your control flows,
# and print your results all in one cell

# %% [markdown]
# ### Bonus: Run this as a single Python script
# *if time is earlier than 7:40*
#
# 1. Create a new notebook (renamed to `speeding_example`) in this folder
# 2. copy the following cells into that notebook (across several cells or in one big cell):
#     1. the pandas import cell
#     2. the data reading cell
#     3. the avg_speed definition cell
#     4. the final working cell
# 3. in the Jupyter menus, click File > Download As > Python (.py)
#     - Click **Keep** if Browser warns file may be dangerous
# 4. Open your terminal (or Anaconda Prompt), navigate to the folder you just saved to
#     - use the `ls` command to see paths, then the `cd` command to navigate
# 5. Type `python speeding_example.py`
# 6. Only your outputs will print in the terminal!
#
# This is a common technique to break down complex projects into different Python scripts that work together. You can `import` scripts you save into new Jupyter notebooks just like libraries and packages!

# %% [markdown]
# ## [Take your workshop feedback survey right here!](http://www.ga.co/introclass)
